# %% [markdown]
# <a href="https://colab.research.google.com/github/faiqnabil/Pembelajaran-Mesin-2026/blob/main/TI_244107020025_FAIQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BAGIAN 1

# %% [markdown]
# 1. Lakukan instalasi library berikut pada notebook

# %%
# !pip install mne

# %%
# !pip install pyprep
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.6 MB/s eta 0:00:00
# ...

# %%
# !pip install scipy

# %%
# !pip install wandb

# %%
# !pip install pyECG --no-deps
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# 2. Kegunaan masing masing library:
#
#
#     a. PyPREP: berfungsi melakukan preprocessing otomatis pada EEG yang     digunakan untuk mendeteksi channel sinyal yang rusak, menghapus nois, dan melakukan re-refencing data sinyal.
#
#     b. SciPY: berfungsi untuk komputasi ilmiah dan matematika tingkat lanjut daan juga didalamnya menyediakan modul aljabar linier, optimasi matematika, statistik dll.
#
#     c. wandb: berfngsi untuk pemantau dan isualisasi eksperimen machine learning atau deep learning yang digunakan untuk membandingkan hasil uji coba dan mendokumentasikan model.
#
#     d. pyECG: berfungsi untuk memproses, menganalisis dan memvisualisasikan data sinyal ECG. dan untuk mempermudah ekstrasi fitur yang penting dari detak jantung seperti gelombang PQRST.

# %% [markdown]
# BAGIAN 2

# %% [markdown]
# 1. Penyalahgunaan AI untuk konten pornografi tanpa izin
#
#     Salah satu kasus yang banyak dibahas dalam literatur hukum Indonesia adalah kasus gambar pornografi palsu (fake pornographic images) yang dibuat menggunakan AI Content Generator terhadap figur publik seperti Taylor Swift.
#
#     Referensi:
#
#     https://law.uii.ac.id/blog/2024/05/02/upaya-penegakan-etika-hukum-terhadap-teknologi-artificial-intelligence-content-generated-analisis-kasus-ai-generated-fake-pornographic-images/
#
# 2. Deepfake untuk pelecehan dan penipuan digital
#
#     Kasus deepfake juga makin menyebar dan telah merusak reputasi banyak orang karena digunakan untuk pelecehan atau penyebaran konten bermuatan SARA, dan berbagai kasus seperti deepfake, pencurian karya, hingga penipuan digital masih berakhir tanpa kejelasan hukum di Indonesia.
#
#     Referensi:
#
#     https://mahasiswaindonesia.id/kecerdasan-buatan-melesat-hukum-tak-kunjung-pesat-apa-yang-harus-dibenahi/
